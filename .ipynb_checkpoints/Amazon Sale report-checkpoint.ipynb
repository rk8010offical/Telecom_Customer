# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Amazon Sale Report.csv")
df
# Out:
#                    Order ID        Date                        Status  \
# 0       405-8078784-5731545  2022-04-30                     Cancelled
# 1       171-9198151-1101146  2022-04-30  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  2022-04-30                       Shipped
# 3       403-9615377-8133951  2022-04-30                     Cancelled
# 4       407-1069790-7240320  2022-04-30                       Shipped
# ...                     ...         ...                           ...
# 121138  406-6001380-7673107  2022-05-31                       Shipped
# 121139  402-9551604-7544318  2022-05-31                       Shipped
# 121140  407-9547469-3152358  2022-05-31                       Shipped
# 121141  402-6184140-0545956  2022-05-31                       Shipped
# 121142  408-7436540-8728312  2022-05-31                       Shipped
#
#        Fulfilment Sales Channel ship-service-level  Category Size  \
# 0        Merchant     Amazon.in           Standard   T-shirt    S
# 1        Merchant     Amazon.in           Standard     Shirt  3XL
# 2          Amazon     Amazon.in          Expedited     Shirt   XL
# 3        Merchant     Amazon.in           Standard   Blazzer    L
# 4          Amazon     Amazon.in          Expedited  Trousers  3XL
# ...           ...           ...                ...       ...  ...
# 121138     Amazon     Amazon.in          Expedited     Shirt   XL
# 121139     Amazon     Amazon.in          Expedited   T-shirt    M
# 121140     Amazon     Amazon.in          Expedited   Blazzer  XXL
# 121141     Amazon     Amazon.in          Expedited   T-shirt   XS
# 121142     Amazon     Amazon.in          Expedited   T-shirt    S
#
#        Courier Status  Qty currency   Amount    ship-city    ship-state  \
# 0          On the Way    0      INR   647.62       MUMBAI   MAHARASHTRA
# 1             Shipped    1      INR   406.00    BENGALURU     KARNATAKA
# 2             Shipped    1      INR   329.00  NAVI MUMBAI   MAHARASHTRA
# 3          On the Way    0      INR   753.33   PUDUCHERRY    PUDUCHERRY
# 4             Shipped    1      INR   574.00      CHENNAI    TAMIL NADU
# ...               ...  ...      ...      ...          ...           ...
# 121138        Shipped    1      INR   517.00    HYDERABAD     TELANGANA
# 121139        Shipped    1      INR   999.00     GURUGRAM       HARYANA
# 121140        Shipped    1      INR   690.00    HYDERABAD     TELANGANA
# 121141        Shipped    1      INR  1199.00        Halol       Gujarat
# 121142        Shipped    1      INR   696.00       Raipur  CHHATTISGARH
#
#         ship-postal-code ship-country    B2B fulfilled-by      Week  Month
# 0                 400081           IN  False    Easy Ship  Saturday  April
# 1                 560085           IN  False    Easy Ship  Saturday  April
# 2                 410210           IN   True        Other  Saturday  April
# 3                 605008           IN  False    Easy Ship  Saturday  April
# 4                 600073           IN  False        Other  Saturday  April
# ...                  ...          ...    ...          ...       ...    ...
# 121138            500013           IN  False        Other   Tuesday    May
# 121139            122004           IN  False        Other   Tuesday    May
# 121140            500049           IN  False        Other   Tuesday    May
# 121141            389350           IN  False        Other   Tuesday    May
# 121142            492014           IN  False        Other   Tuesday    May
#
# [121143 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121143 entries, 0 to 121142
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            121143 non-null  object
#  1   Date                121143 non-null  object
#  2   Status              121143 non-null  object
#  3   Fulfilment          121143 non-null  object
#  4   Sales Channel       121143 non-null  object
#  5   ship-service-level  121143 non-null  object
#  6   Category            121143 non-null  object
#  7   Size                121143 non-null  object
#  8   Courier Status      121143 non-null  object
#  9   Qty                 121143 non-null  int64
#  10  currency            121143 non-null  object
#  11  Amount              121143 non-null  float64
#  12  ship-city           121143 non-null  object
#  13  ship-state          121143 non-null  object
#  14  ship-postal-code    121143 non-null  int64
#  15  ship-country        121143 non-null  object
#  16  B2B                 121143 non-null  bool
#  17  fulfilled-by        121143 non-null  object
#  18  Week                121143 non-null  object
#  19  Month               121143 non-null  object
# dtypes: bool(1), float64(1), int64(2), object(16)
# memory usage: 17.7+ MB

# %%
df.dropna(inplace=True)
df.to_csv("Amazon Sale Report.csv", index=False)

# %%
df["ship-postal-code"] = df["ship-postal-code"].astype("int")

# %%
# Converting 'Date' column to datetime
df["Date"] = pd.to_datetime(df["Date"])

# Extracting the day name and month name
df["Week"] = df["Date"].dt.day_name()  # Day name
df["Month"] = df["Date"].dt.month_name()  # Month name

# %%
df.to_csv("Amazon Sale Report.csv", index=False)

# %%
df.describe()
# Out:
#                                 Date            Qty         Amount  \
# count                         121143  121143.000000  121143.000000
# mean   2022-05-12 12:11:22.182214144       0.961252     648.576874
# min              2022-03-31 00:00:00       0.000000       0.000000
# 25%              2022-04-20 00:00:00       1.000000     449.000000
# 50%              2022-05-10 00:00:00       1.000000     605.000000
# 75%              2022-06-04 00:00:00       1.000000     788.000000
# max              2022-06-29 00:00:00       8.000000    5584.000000
# std                              NaN       0.214276     281.196896
#
#        ship-postal-code
# count     121143.000000
# mean      463623.724507
# min       110001.000000
# 25%       382421.000000
# 50%       500032.000000
# 75%       600020.000000
# max       989898.000000
# std       191301.588170

# %%
df.describe(include="object")
# Out:
#                    Order ID   Status Fulfilment Sales Channel  \
# count                121143   121143     121143        121143
# unique               112861       12          2             1
# top     171-5057375-2831560  Shipped     Amazon     Amazon.in
# freq                     12    77589      83629        121143
#
#        ship-service-level Category    Size Courier Status currency  ship-city  \
# count              121143   121143  121143         121143   121143     121143
# unique                  2        9      11              3        1       8697
# top             Expedited  T-shirt       M        Shipped      INR  BENGALURU
# freq                82713    47038   20965         109458   121143      10675
#
#          ship-state ship-country fulfilled-by    Week   Month
# count        121143       121143       121143  121143  121143
# unique           68            1            2       7       4
# top     MAHARASHTRA           IN        Other  Sunday   April
# freq          21084       121143        83629   18495   46049

# %%
ax=sns.countplot(x="Size", data= df)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# #Most of the people buy M-Size Tshirt in this data

# %%
sns.countplot(x="Courier Status", data= df, hue="Status")
plt.title("Shipping status")
plt.show()

# %% [markdown]
# #Majority to the order are shipping through The couiers

# %%
ax=sns.countplot(x="Category", data= df)
for bars in ax.containers:
    ax.bar_label(bars)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #Tshirt is hightes sale in this columns

# %%
check_b2b=df["B2B"].value_counts()
plt.pie(check_b2b, labels=check_b2b.index, autopct="%1.1f%%")
plt.show()

# %% [markdown]
# #Most of the case retail is a buyer and whole saler is only 0.7% buyer

# %%
plt.figure(figsize=(10, 6))
ax=sns.barplot(x="Category", y="Amount", data=df)
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# #The hightest Amount of Tshirt and The Lowest Amount of Watch

# %%
top10_state = df["ship-state"].value_counts().head(10)
plt.figure(figsize=(10, 6))
ax = sns.countplot(x="ship-state", data= df[df["ship-state"].isin(top10_state.index)])
ax.bar_label(ax.containers[0])
plt.title("Distribution of state")
plt.xticks(rotation=90) 
plt.show()

# %% [markdown]
# #Maharashtra is highest distribution state in this data

# %%
top10_city = df["ship-city"].value_counts().head(10)
plt.figure(figsize=(10, 6))
ax = sns.countplot(x="ship-city", data= df[df["ship-city"].isin(top10_city.index)])
ax.bar_label(ax.containers[0])
plt.title("Distribution of city")
plt.xticks(rotation=90) 
plt.show()

# %% [markdown]
# #Bengluru is highest distribution city in this data

# %%
plt.figure(figsize=(10, 6))
ax=sns.barplot(x="Category", y="Amount", data=df, hue="Week")
plt.show()

# %% [markdown]
# #Shoes is distribution in the hight amount of tuesday  and watch is the lowest amount of sunday

# %%
plt.figure(figsize=(10, 6))
ax=sns.barplot(x="Category", y="Amount", data=df, hue="Month")
plt.show()

# %% [markdown]
# #Perfume is distribution in the highest price of March month and watch is distribution in the lowest price of June month
